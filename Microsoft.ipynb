# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# %%
# !pip install datascience
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datascience in /usr/local/lib/python3.9/dist-packages (0.17.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from datascience) (1.10.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.9/dist-packages (from datascience) (7.34.0)
# Requirement already satisfied: branca in /usr/local/lib/python3.9/dist-packages (from datascience) (0.6.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from datascience) (3.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from datascience) (67.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from datascience) (1.22.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from datascience) (5.13.1)
# Requirement already satisfied: folium>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from datascience) (0.14.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datascience) (1.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from folium>=0.9.1->datascience) (2.27.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.9/dist-packages (from folium>=0.9.1->datascience) (3.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->datascience) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->datascience) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->datascience) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->datascience) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->datascience) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->datascience) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->datascience) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->datascience) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.0.0->datascience) (4.39.3)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython->datascience) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython->datascience) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython->datascience) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython->datascience) (2.14.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython->datascience) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython->datascience) (0.1.6)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython->datascience) (5.7.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython->datascience) (0.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datascience) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->datascience) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->datascience) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython->datascience) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2>=2.9->folium>=0.9.1->datascience) (2.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython->datascience) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->datascience) (0.2.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->datascience) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->folium>=0.9.1->datascience) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->folium>=0.9.1->datascience) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->folium>=0.9.1->datascience) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->folium>=0.9.1->datascience) (2.0.12)
# Installing collected packages: jedi
# Successfully installed jedi-0.18.2

# %%
from datascience import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read the CSV file
df = pd.read_csv("/content/drive/MyDrive/Code/microsoftRemaster.csv")
df.tail()
# Out:
#             date    Open    High     Low   Close  Adj Close    Volume  \
# 1322  2023-04-13  283.59  289.90  283.17  289.84     289.84  24205200
# 1323  2023-04-14  287.00  288.48  283.69  286.14     286.14  20973900
# 1324  2023-04-17  289.93  291.58  286.20  288.80     288.80  23836223
# 1325  2023-04-18  297.57  297.76  287.01  288.37     288.37  20149400
# 1326  2023-04-19  285.99  289.05  284.54  288.45     288.45  17114800
#
#       DollarPrice  DollarChangeRate  OilPrice  OilChangeRate  Interest  \
# 1322       100.89             -0.12     82.52           0.35      4.83
# 1323       101.66              0.12     82.47          -0.06      4.83
# 1324       102.10              0.42     80.84          -1.99      4.83
# 1325       101.72             -0.38     80.90           0.09      4.83
# 1326       101.99              0.24     78.89          -2.44      4.83
#
#       InterestRateChange  copper  copperChangeRate  nextdayprice  result
# 1322                 0.0  4.1385            0.0105        286.14     0.0
# 1323                 0.0  4.1102            0.0900        288.80     1.0
# 1324                 0.0  4.0648           -0.2000        288.37     0.0
# 1325                 0.0  4.0850            0.4700        288.45     1.0
# 1326                 0.0  4.0685           -0.5600           NaN     NaN

# %%
# Drop the nextdayprice and result columns
df = df.drop(['nextdayprice', 'result'], axis=1)

# %%
df.tail()
# Out:
#             date    Open    High     Low   Close  Adj Close    Volume  \
# 1322  2023-04-13  283.59  289.90  283.17  289.84     289.84  24205200
# 1323  2023-04-14  287.00  288.48  283.69  286.14     286.14  20973900
# 1324  2023-04-17  289.93  291.58  286.20  288.80     288.80  23836223
# 1325  2023-04-18  297.57  297.76  287.01  288.37     288.37  20149400
# 1326  2023-04-19  285.99  289.05  284.54  288.45     288.45  17114800
#
#       DollarPrice  DollarChangeRate  OilPrice  OilChangeRate  Interest  \
# 1322       100.89             -0.12     82.52           0.35      4.83
# 1323       101.66              0.12     82.47          -0.06      4.83
# 1324       102.10              0.42     80.84          -1.99      4.83
# 1325       101.72             -0.38     80.90           0.09      4.83
# 1326       101.99              0.24     78.89          -2.44      4.83
#
#       InterestRateChange  copper  copperChangeRate
# 1322                 0.0  4.1385            0.0105
# 1323                 0.0  4.1102            0.0900
# 1324                 0.0  4.0648           -0.2000
# 1325                 0.0  4.0850            0.4700
# 1326                 0.0  4.0685           -0.5600

# %%
# Convert the 'date' column to datetime format and set it as the index of the dataframe
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

# %%
# Define the feature and target variables
X = df.iloc[:, :-1].values
y = df.iloc[:, 3:4].values

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Scale the data using MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
y_train = scaler.fit_transform(y_train)
y_test = scaler.transform(y_test)

# %%
# Reshape the data for LSTM
feature_length = X_train.shape[1]
X_train = X_train.reshape(X_train.shape[0], feature_length, 1)
X_test = X_test.reshape(X_test.shape[0], feature_length, 1)

# %% [markdown]
# #Building LSTM Model

# %%
# Define the LSTM model
model = Sequential([
    LSTM(100, return_sequences=True, input_shape=(feature_length, 1)),
    Dropout(0.3),
    LSTM(100, return_sequences=False),
    Dropout(0.3),
    Dense(1),
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=12,
    verbose=1,
)
# Out:
# Epoch 1/100
# 89/89 [==============================] - 8s 19ms/step - loss: 0.0246
# Epoch 2/100
# 89/89 [==============================] - 2s 19ms/step - loss: 0.0043
# Epoch 3/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0045
# Epoch 4/100
# 89/89 [==============================] - 2s 22ms/step - loss: 0.0036
# Epoch 5/100
# 89/89 [==============================] - 3s 31ms/step - loss: 0.0026
# Epoch 6/100
# 89/89 [==============================] - 2s 26ms/step - loss: 0.0032
# Epoch 7/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0030
# Epoch 8/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0018
# Epoch 9/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0020
# Epoch 10/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0020
# Epoch 11/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0015
# Epoch 12/100
# 89/89 [==============================] - 3s 31ms/step - loss: 0.0019
# Epoch 13/100
# 89/89 [==============================] - 3s 29ms/step - loss: 0.0027
# Epoch 14/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0017
# Epoch 15/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0014
# Epoch 16/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0013
# Epoch 17/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0014
# Epoch 18/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0014
# Epoch 19/100
# 89/89 [==============================] - 3s 29ms/step - loss: 0.0012
# Epoch 20/100
# 89/89 [==============================] - 3s 31ms/step - loss: 0.0014
# Epoch 21/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0013
# Epoch 22/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0014
# Epoch 23/100
# 89/89 [==============================] - 2s 19ms/step - loss: 0.0013
# Epoch 24/100
# 89/89 [==============================] - 2s 19ms/step - loss: 0.0016
# Epoch 25/100
# 89/89 [==============================] - 2s 19ms/step - loss: 0.0011
# Epoch 26/100
# 89/89 [==============================] - 2s 24ms/step - loss: 0.0014
# Epoch 27/100
# 89/89 [==============================] - 3s 32ms/step - loss: 0.0011
# Epoch 28/100
# 89/89 [==============================] - 2s 24ms/step - loss: 0.0010
# Epoch 29/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.7050e-04
# Epoch 30/100
# 89/89 [==============================] - 2s 26ms/step - loss: 0.0012
# Epoch 31/100
# 89/89 [==============================] - 3s 30ms/step - loss: 0.0011
# Epoch 32/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0011
# Epoch 33/100
# 89/89 [==============================] - 3s 30ms/step - loss: 0.0012
# Epoch 34/100
# 89/89 [==============================] - 3s 30ms/step - loss: 9.6381e-04
# Epoch 35/100
# 89/89 [==============================] - 2s 19ms/step - loss: 8.6720e-04
# Epoch 36/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0012
# Epoch 37/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.8059e-04
# Epoch 38/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.6454e-04
# Epoch 39/100
# 89/89 [==============================] - 2s 19ms/step - loss: 9.1739e-04
# Epoch 40/100
# 89/89 [==============================] - 2s 25ms/step - loss: 0.0011
# Epoch 41/100
# 89/89 [==============================] - 3s 32ms/step - loss: 0.0010
# Epoch 42/100
# 89/89 [==============================] - 2s 23ms/step - loss: 0.0010
# Epoch 43/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.0463e-04
# Epoch 44/100
# 89/89 [==============================] - 2s 21ms/step - loss: 9.1683e-04
# Epoch 45/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.4553e-04
# Epoch 46/100
# 89/89 [==============================] - 2s 20ms/step - loss: 0.0012
# Epoch 47/100
# 89/89 [==============================] - 2s 23ms/step - loss: 9.1173e-04
# Epoch 48/100
# 89/89 [==============================] - 3s 32ms/step - loss: 9.1764e-04
# Epoch 49/100
# 89/89 [==============================] - 2s 25ms/step - loss: 7.1576e-04
# Epoch 50/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.7913e-04
# Epoch 51/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.4357e-04
# Epoch 52/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.0714e-04
# Epoch 53/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.5470e-04
# Epoch 54/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.4004e-04
# Epoch 55/100
# 89/89 [==============================] - 3s 32ms/step - loss: 8.5143e-04
# Epoch 56/100
# 89/89 [==============================] - 3s 29ms/step - loss: 0.0010
# Epoch 57/100
# 89/89 [==============================] - 2s 21ms/step - loss: 7.6815e-04
# Epoch 58/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.8853e-04
# Epoch 59/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.1096e-04
# Epoch 60/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.4862e-04
# Epoch 61/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.4180e-04
# Epoch 62/100
# 89/89 [==============================] - 3s 29ms/step - loss: 7.3079e-04
# Epoch 63/100
# 89/89 [==============================] - 3s 30ms/step - loss: 8.1778e-04
# Epoch 64/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.9646e-04
# Epoch 65/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.4196e-04
# Epoch 66/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.5038e-04
# Epoch 67/100
# 89/89 [==============================] - 2s 20ms/step - loss: 7.2218e-04
# Epoch 68/100
# 89/89 [==============================] - 2s 20ms/step - loss: 7.9343e-04
# Epoch 69/100
# 89/89 [==============================] - 2s 25ms/step - loss: 0.0012
# Epoch 70/100
# 89/89 [==============================] - 3s 33ms/step - loss: 9.0464e-04
# Epoch 71/100
# 89/89 [==============================] - 2s 21ms/step - loss: 7.8852e-04
# Epoch 72/100
# 89/89 [==============================] - 2s 20ms/step - loss: 7.6727e-04
# Epoch 73/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.4315e-04
# Epoch 74/100
# 89/89 [==============================] - 2s 19ms/step - loss: 7.4922e-04
# Epoch 75/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.0866e-04
# Epoch 76/100
# 89/89 [==============================] - 2s 23ms/step - loss: 0.0011
# Epoch 77/100
# 89/89 [==============================] - 3s 31ms/step - loss: 0.0010
# Epoch 78/100
# 89/89 [==============================] - 2s 25ms/step - loss: 8.5186e-04
# Epoch 79/100
# 89/89 [==============================] - 2s 20ms/step - loss: 6.9168e-04
# Epoch 80/100
# 89/89 [==============================] - 2s 20ms/step - loss: 6.6183e-04
# Epoch 81/100
# 89/89 [==============================] - 2s 20ms/step - loss: 6.6065e-04
# Epoch 82/100
# 89/89 [==============================] - 2s 19ms/step - loss: 7.1026e-04
# Epoch 83/100
# 89/89 [==============================] - 2s 19ms/step - loss: 6.5716e-04
# Epoch 84/100
# 89/89 [==============================] - 3s 30ms/step - loss: 8.4349e-04
# Epoch 85/100
# 89/89 [==============================] - 3s 30ms/step - loss: 7.4994e-04
# Epoch 86/100
# 89/89 [==============================] - 2s 21ms/step - loss: 7.7922e-04
# Epoch 87/100
# 89/89 [==============================] - 2s 20ms/step - loss: 6.7815e-04
# Epoch 88/100
# 89/89 [==============================] - 2s 20ms/step - loss: 7.5596e-04
# Epoch 89/100
# 89/89 [==============================] - 2s 20ms/step - loss: 7.1801e-04
# Epoch 90/100
# 89/89 [==============================] - 2s 20ms/step - loss: 7.9407e-04
# Epoch 91/100
# 89/89 [==============================] - 2s 28ms/step - loss: 6.7378e-04
# Epoch 92/100
# 89/89 [==============================] - 3s 31ms/step - loss: 8.2076e-04
# Epoch 93/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.1878e-04
# Epoch 94/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.7999e-04
# Epoch 95/100
# 89/89 [==============================] - 2s 20ms/step - loss: 8.1664e-04
# Epoch 96/100
# 89/89 [==============================] - 2s 20ms/step - loss: 9.7999e-04
# Epoch 97/100
# 89/89 [==============================] - 2s 20ms/step - loss: 7.9894e-04
# Epoch 98/100
# 89/89 [==============================] - 2s 26ms/step - loss: 8.6784e-04
# Epoch 99/100
# 89/89 [==============================] - 3s 32ms/step - loss: 7.7612e-04
# Epoch 100/100
# 89/89 [==============================] - 2s 22ms/step - loss: 7.0043e-04

# %%
# Make predictions using the test set
y_pred = model.predict(X_test)
# Out:
# 9/9 [==============================] - 1s 8ms/step

# %% [markdown]
# ##Model's Performance in test

# %%
# Invert the scaling of the predictions and the actual values
y_pred = scaler.inverse_transform(y_pred)
y_test = scaler.inverse_transform(y_test)

# %%
# Print the RMSE of the predictions
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 12.1235399839

# %% [markdown]
# #Make Predictions

# %%
# Add the 'date' column back to the dataframe
df['date'] = df.index

# %%
# Create a dataframe to store the predicted and actual values of closing price along with their corresponding dates
test_dates = df.loc[df.index[-len(y_test):], 'date'].values
results = pd.DataFrame({'Date': test_dates, 'Predicted closing price': y_pred.flatten(), 'Actual closing price': y_test.flatten()})

# %%
# Calculate the result column based on the predicted and actual values of closing price
results['result'] = np.where(results['Predicted closing price'].shift(-1) > results['Predicted closing price'], 1, 0)

# %%
# Print the results
pd.set_option('display.max_rows', None)  # To display all the rows of the dataframe
print(results)
# Out:
#           Date  Predicted closing price  Actual closing price  result
# 0   2022-03-28               301.886963            310.700012       1
# 1   2022-03-29               311.538452            315.410004       0
# 2   2022-03-30               310.763062            313.859985       0
# 3   2022-03-31               305.368530            308.309998       0
# 4   2022-04-01               302.870239            309.420013       1
# 5   2022-04-04               305.819244            314.970001       0
# 6   2022-04-05               304.792419            310.880005       0
# 7   2022-04-06               298.610718            299.500000       0
# 8   2022-04-07               295.154999            301.369995       0
# 9   2022-04-08               293.374268            296.970001       0
# 10  2022-04-11               284.406128            285.260010       0
# 11  2022-04-12               279.108063            282.059998       1
# 12  2022-04-13               281.161438            287.619995       0
# 13  2022-04-14               276.207184            279.829987       0
# 14  2022-04-18               271.750549            280.519989       1
# 15  2022-04-19               276.090546            285.299988       1
# 16  2022-04-20               284.173157            286.359985       0
# 17  2022-04-21               279.480530            280.809998       0
# 18  2022-04-22               269.644867            274.029999       0
# 19  2022-04-25               269.411438            280.720001       0
# 20  2022-04-26               266.212463            270.220001       1
# 21  2022-04-27               276.020416            283.220001       1
# 22  2022-04-28               276.649750            289.630005       1
# 23  2022-04-29               279.988800            277.519989       0
# 24  2022-05-02               269.911163            284.470001       1
# 25  2022-05-03               276.870911            281.779999       1
# 26  2022-05-04               282.911560            289.980011       0
# 27  2022-05-05               266.210205            277.350006       1
# 28  2022-05-06               267.568085            274.730011       0
# 29  2022-05-09               260.999939            264.579987       1
# 30  2022-05-10               261.607025            269.500000       0
# 31  2022-05-11               257.208679            260.549988       0
# 32  2022-05-12               241.400894            255.350006       1
# 33  2022-05-13               251.835297            261.119995       1
# 34  2022-05-16               253.624130            261.500000       1
# 35  2022-05-17               261.378754            266.820007       0
# 36  2022-05-18               247.820053            254.080002       1
# 37  2022-05-19               251.236847            253.139999       0
# 38  2022-05-20               243.854630            252.559998       1
# 39  2022-05-23               255.670792            260.649994       0
# 40  2022-05-24               252.059723            259.619995       1
# 41  2022-05-25               252.354416            262.519989       1
# 42  2022-05-26               257.362305            265.899994       1
# 43  2022-05-27               263.797821            273.239990       1
# 44  2022-05-31               264.627167            271.869995       0
# 45  2022-06-01               261.631042            272.420013       1
# 46  2022-06-02               265.760529            274.579987       0
# 47  2022-06-03               260.766449            270.019989       0
# 48  2022-06-06               260.429230            268.750000       1
# 49  2022-06-07               261.620941            272.500000       0
# 50  2022-06-08               260.652710            270.410004       0
# 51  2022-06-09               254.659515            264.790009       0
# 52  2022-06-10               242.122086            252.990005       0
# 260 2023-04-12               273.639954            283.490000       1
# 261 2023-04-13               277.125122            289.840000       0
# 262 2023-04-14               274.635590            286.140000       1
# 263 2023-04-17               275.317932            288.800000       1
# 264 2023-04-18               283.599121            288.370000       0
# 265 2023-04-19               274.660461            288.450000       0

# %% [markdown]
# #Evaluating the Model Performance

# %%
# Calculate the number of times the model correctly estimated the result column in the test set
correct_predictions = sum(results['result'][:-1] == (results['Actual closing price'][1:].values > results['Actual closing price'][:-1].values))

# Calculate the total number of predictions in the test set
total_predictions = len(results) - 1

# Calculate the percentage of correct predictions in the test set
accuracy = (correct_predictions / total_predictions) * 100

# Print the accuracy
print(f"The model made {correct_predictions} correct predictions out of {total_predictions} total predictions in the test set. The accuracy is {accuracy:.2f}%.")
# Out:
# The model made 191 correct predictions out of 265 total predictions in the test set. The accuracy is 72.08%.

# %% [markdown]
# ##Predicting the next day's closing price

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Scale the data using MinMaxScaler
feature_scaler = MinMaxScaler()
X_train = feature_scaler.fit_transform(X_train)
X_test = feature_scaler.transform(X_test)

target_scaler = MinMaxScaler()
y_train = target_scaler.fit_transform(y_train)
y_test = target_scaler.transform(y_test)

# Reshape the data for LSTM
feature_length = X_train.shape[1]
X_train = X_train.reshape(X_train.shape[0], feature_length, 1)
X_test = X_test.reshape(X_test.shape[0], feature_length, 1)

# %%
# Scale the entire dataset using the same MinMaxScaler
entire_data_scaled = feature_scaler.transform(X)

# Reshape the input data to match the input shape of the LSTM model
entire_data_scaled = entire_data_scaled.reshape(entire_data_scaled.shape[0], feature_length, 1)

# Get the most recent data point
last_data_point = entire_data_scaled[-1].reshape(1, feature_length, 1)

# Create a new input data point for 04-06-2023 by shifting the existing data by one day
# and using the most recent predicted closing price as the new input
new_input = np.roll(last_data_point, -1, axis=1)
new_input[0, -1, 0] = target_scaler.transform([[y_pred[-1][0]]])[0][0]

# Pass the new input data through the model to get the prediction
next_day_prediction = model.predict(new_input)

# Inverse transform the prediction to get the actual predicted closing price
next_day_prediction = target_scaler.inverse_transform(next_day_prediction)

# Print the predicted closing price for 04-06-2023
print(f"Estimated Predicted Closing Price for 04-07-2023: {next_day_prediction[0][0]:.2f}")
# Out:
# 1/1 [==============================] - 0s 37ms/step
# Estimated Predicted Closing Price for 04-07-2023: 256.64

# %% [markdown]
# ##Comparing current date's predicted price and tomorrow's predicted price to calculate the trend estimation

# %%
# Correct the date for 2023-04-05 in the results DataFrame
results.loc[results['Date'] == pd.to_datetime('2020-04-17'), 'Date'] = pd.to_datetime('2023-04-17')

# Get the predicted closing price for 2023-04-05 from the results dataframe
pred_closing_price_2023_04_17 = results[results['Date'] == pd.to_datetime('2023-04-14')]['Predicted closing price'].values[0]

# Calculate the result column for 2023-04-06
result = 1 if next_day_prediction > pred_closing_price_2023_04_17 else 0

# Print the predicted closing prices and the result column
print(f"Predicted Closing Price on 2023-04-06: {pred_closing_price_2023_04_17}")
print(f"Estimated Predicted Closing Price on 2023-04-07: {next_day_prediction[0][0]}")
print(f"Result: {result}")
# Out:
# Predicted Closing Price on 2023-04-06: 280.0897521972656
# Estimated Predicted Closing Price on 2023-04-07: 263.8965759277344
# Result: 0
